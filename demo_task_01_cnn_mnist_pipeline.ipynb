# %% [markdown]
# ## Pipeline from input dataset folder to trained model

# %%
# %run -i task_01_cnn_mnist_pipeline.py -i ./data
# Out:
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# ## Training and validation loss (cross entropy) and accuracy versus epoch

# %%
import matplotlib.pyplot as plt
train_acc = [0.937, 0.9824583333333333, 0.9859375, 0.9864375, 0.9862708333333333, 0.9877708333333334, 0.987625, 0.9885416666666667, 0.9879583333333334]
val_acc = [0.9791666666666666, 0.9860833333333333, 0.9703333333333334, 0.9850833333333333, 0.9859166666666667, 0.9826666666666667, 0.9839166666666667, 0.9835833333333334, 0.9834166666666667]
train_loss = [0.20109333818838543, 0.06619865674522832, 0.05929943035684224, 0.05994056506849324, 0.06446589857799451, 0.062321169751541484, 0.06047324257350753, 0.05882835998714637, 0.07344525412092603]
val_loss = [0.07797512601754474, 0.05791405490212037, 0.10723861258042355, 0.0628735159033143, 0.053639876025175906, 0.06318130778199217, 0.09247073725437485, 0.14447596012539976, 0.08119952128959024]

epochs = range(1, len(train_acc) + 1)

plt.plot(epochs, train_acc, 'bo-', label = 'Training acc')
plt.plot(epochs, val_acc, 'ro-', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, train_loss, 'bo-', label = 'Training loss')
plt.plot(epochs, val_loss, 'ro-', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# After reviewing the training history of validation set performance, we can conclude the best model is from epoch 5.
